# %%
import numpy as np

shape = (150, 100)
eps = np.sqrt(6. / np.sum(shape))
W = np.random.uniform(-eps, eps, size=shape)
shape = (100, 5)
eps = np.sqrt(6. / np.sum(shape))
U = np.random.uniform(-eps, eps, size=shape)

# %%
0.5 * 0.001 * np.sum(W ** 2) + 0.5 * 0.001 * np.sum(U ** 2)
# Out:
# 0.064779034876511044

# %%
2.36988854408 - 2.3061831 - 0.0637055113912
# Out:
# -6.731119998881763e-08
